# %%
import pandas as pd

# %%
epl = pd.read_csv('../data/raw/arsenal_epl_2025_26.csv')
ucl = pd.read_csv('../data/raw/arsenal_ucl_2025_26.csv')

# %%
print("EPL Dataset:")
print(epl.columns.tolist())
print(f"Total matches: {len(epl)}")
print(epl.head())
# Out:
# EPL Dataset:
# ['Match Number', 'Round Number', 'Date', 'Location', 'Home Team', 'Away Team', 'Result']
# Total matches: 38
#    Match Number  Round Number              Date          Location  Home Team  \
# 0             9             1  17/08/2025 16:30      Old Trafford    Man Utd
# 1            11             2  23/08/2025 17:30  Emirates Stadium    Arsenal
# 2            25             3  31/08/2025 16:30           Anfield  Liverpool
# 3            31             4  13/09/2025 12:30  Emirates Stadium    Arsenal
# 4            41             5  21/09/2025 16:30  Emirates Stadium    Arsenal
#
#        Away Team Result
# 0        Arsenal  0 - 1
# 1          Leeds  5 - 0
# 2        Arsenal  1 - 0
# 3  Nott'm Forest  3 - 0
# 4       Man City  1 - 1

# %%
print("\n" + "="*50)
print("UCL Dataset:")
print(ucl.columns.tolist())
print(f"Total matches: {len(ucl)}")
print(ucl.head())
# Out:
# ...
# UCL Dataset:
# ['Match Number', 'Round Number', 'Date', 'Location', 'Home Team', 'Away Team', 'Result']
# Total matches: 14
#    Match Number Round Number              Date              Location  \
# 0             2            1  16/09/2025 17:45  Estadio de San Mamés
# 1            30            2  01/10/2025 20:00       Arsenal Stadium
# 2            39            3  21/10/2025 20:00       Arsenal Stadium
# 3            56            4  04/11/2025 18:45            Eden Arena
# 4            86            5  26/11/2025 21:00       Arsenal Stadium
#
#        Home Team       Away Team Result
# 0  Athletic Club         Arsenal  0 - 2
# 1        Arsenal      Olympiacos  2 - 0
# 2        Arsenal          Atleti  4 - 0
# 3   Slavia Praha         Arsenal  0 - 3
# 4        Arsenal  Bayern München  3 - 1
